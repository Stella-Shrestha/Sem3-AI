# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/Titanic-Dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Problem 1
# Create a DataFrame called Fare that contains only the Fare column of the Titanic ddataset.Print the head of the reuslt

# %%
fare = df[['Fare']]
print(fare.head())
# Out:
#       Fare
# 0   7.2500
# 1  71.2833
# 2   7.9250
# 3  53.1000
# 4   8.0500

# %% [markdown]
# Create a DataFrame call class_age that contains only the pclass and Age columns of the Titanic dataset, in that order.Print the head of the result

# %%
class_Age = df[['Pclass','Age']]
class_Age.head()
# Out:
#    Pclass   Age
# 0       3  22.0
# 1       1  38.0
# 2       3  26.0
# 3       1  35.0
# 4       3  35.0

# %% [markdown]
# Create a DataFrame called survived_gender that contains the survived and Sex columns of the Titanic dataset.

# %%
survived_gender = df[['Survived','Sex']]
survived_gender.head()
# Out:
#    Survived     Sex
# 0         0    male
# 1         1  female
# 2         1  female
# 3         1  female
# 4         0    male

# %% [markdown]
# Problem 2 Filter the Titanic dataset for cases where

# %%
fare_gt_100 = df[df['Fare']>100][['Fare']]
fare_gt_100.head()
# Out:
#          Fare
# 27   263.0000
# 31   146.5208
# 88   263.0000
# 118  247.5208
# 195  146.5208

# %% [markdown]
# Filter the Titanic dataset for cases where the passenger’s class (Pclass) is 1, assigning it to
# first class.View the printed result.

# %%
first_class = df[df['Pclass'] == 1][['Pclass']]
first_class.head()
# Out:
#     Pclass
# 1        1
# 3        1
# 6        1
# 11       1
# 23       1

# %% [markdown]
# Filter the Titanic dataset for cases where the passenger’s age is less than 18 and the passenger
# is female (Sex is "female"), assigning it to female under 18. View the printed result.

# %%
female_under_18 = df[(df['Age']<18) & (df['Sex'] == 'female')][['Age','Sex']]
female_under_18.head()
# Out:
#      Age     Sex
# 9   14.0  female
# 10   4.0  female
# 14  14.0  female
# 22  15.0  female
# 24   8.0  female

# %% [markdown]
# Filter the Titanic dataset for passengers whose Embarked port is either "C" (Cherbourg) or "S"
# (Southampton), assigning the result to embarked c or s. View the printed result.

# %%
embarked_c_or_a = df[(df['Embarked']=="C") | (df['Embarked'] == "S")][['Embarked']]
embarked_c_or_a.head()
# Out:
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %% [markdown]
# Filter the Titanic dataset for passengers whose Pclass is in the list [1, 2] (indicating first
# or second class), assigning the result to first second class.View the printed result.

# %%
first_second_class = df[df['Pclass'].isin([1,2])][['Pclass']]
first_second_class.head()
# Out:
#     Pclass
# 1        1
# 3        1
# 6        1
# 9        2
# 11       1

# %% [markdown]
# Add a column to the Titanic dataset, fare per year, containing the fare divided by the age of
# the passenger(i.e., Fare/Age).

# %%
fare_year_age = df['Fare']/df['Age']
fare_year_age.head()
# Out:
# 0    0.329545
# 1    1.875876
# 2    0.304808
# 3    1.517143
# 4    0.230000
# dtype: float64

# %% [markdown]
# Subset rows where fare per year is higher than 5, assigning this to high fare age.

# %%
high_fare_age = df[df['Fare'] > 5][['Fare']]
high_fare_age.head()
# Out:
#       Fare
# 0   7.2500
# 1  71.2833
# 2   7.9250
# 3  53.1000
# 4   8.0500

# %% [markdown]
# Sort high fare age by descending fare per year, assigning this to high fare age srt.

# %%
high_fare_age_srt = high_fare_age.sort_values(by='Fare', ascending = False)
high_fare_age_srt.head()
# Out:
#          Fare
# 679  512.3292
# 258  512.3292
# 737  512.3292
# 27   263.0000
# 438  263.0000

# %% [markdown]
# Select only the Name and fare per year columns of high fare age srt and save the result as result.

# %%
result = df[df['Fare'].isin(high_fare_age_srt['Fare'])][['Name','Fare']]
result = result.sort_values(by='Fare', ascending = False)
result.head()
# Out:
#                                    Name      Fare
# 679  Cardeza, Mr. Thomas Drake Martinez  512.3292
# 258                    Ward, Miss. Anna  512.3292
# 737              Lesurer, Mr. Gustave J  512.3292
# 27       Fortune, Mr. Charles Alexander  263.0000
# 438                   Fortune, Mr. Mark  263.0000

# %% [markdown]
# Add a column to the Titanic dataset, fare per class, containing the fare divided by the passenger
# class i.e. Fare / Pclass.

# %%
df['fare_per_class'] = df['Fare'] / df['Pclass']
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  fare_per_class
# 0      0         A/5 21171   7.2500   NaN        S        2.416667
# 1      0          PC 17599  71.2833   C85        C       71.283300
# 2      0  STON/O2. 3101282   7.9250   NaN        S        2.641667
# ...

# %% [markdown]
# Subset rows where the passenger is male (Sex is ”male”) and an adult (Age is greater than or equal
# to 18), assigning this to adult males.

# %%
adult_males = df[(df['Sex'] == 'male') & (df['Age'] > 18)][['Sex', 'Age', 'fare_per_class']]
adult_males.head()
# Out:
#      Sex   Age  fare_per_class
# 0   male  22.0        2.416667
# 4   male  35.0        2.683333
# 6   male  54.0       51.862500
# 12  male  20.0        2.683333
# 13  male  39.0       10.425000

# %% [markdown]
# Sort adult males by descending fare per class, assigning this to adult males srt.

# %%
adult_males_srt = adult_males.sort_values(by = 'fare_per_class', ascending = False)
adult_males_srt.head()
# Out:
#       Sex   Age  fare_per_class
# 679  male  36.0        512.3292
# 737  male  35.0        512.3292
# 27   male  19.0        263.0000
# 438  male  64.0        263.0000
# 118  male  24.0        247.5208

# %% [markdown]
# Select only the Name, Age, and fare per class columns of adult males sr and save the result
# as result.

# %%
result = df[df['fare_per_class'].isin(adult_males_srt['fare_per_class'])][['Name','Age','fare_per_class']]
result = result.sort_values(by='fare_per_class', ascending = False)
result.head()
# Out:
#                                    Name   Age  fare_per_class
# 679  Cardeza, Mr. Thomas Drake Martinez  36.0        512.3292
# 258                    Ward, Miss. Anna  35.0        512.3292
# 737              Lesurer, Mr. Gustave J  35.0        512.3292
# 438                   Fortune, Mr. Mark  64.0        263.0000
# 27       Fortune, Mr. Charles Alexander  19.0        263.0000

# %% [markdown]
# Look at the result.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  fare_per_class
# 0      0         A/5 21171   7.2500   NaN        S        2.416667
# 1      0          PC 17599  71.2833   C85        C       71.283300
# 2      0  STON/O2. 3101282   7.9250   NaN        S        2.641667
# ...

# %% [markdown]
# Calculate the total Fare paid across all passengers in the Titanic dataset.

# %%
total_fare = df['Fare'].sum()
total_fare
# Out:
# 28693.9493

# %% [markdown]
# Subset for passengers in first class (Pclass is 1) and calculate their total fare.

# %%
total_firstclass_fare = df[df['Pclass']==1]['Fare'].sum()
total_firstclass_fare
# Out:
# 18177.4125

# %% [markdown]
# Divide the totals for each class by the overall total fare to get the proportion of fare revenue by class.

# %%
fare_proportion_firstclass = total_firstclass_fare/total_fare
fare_proportion_firstclass
# Out:
# 0.6334928771899656

# %% [markdown]
# Do the same for second class (Pclass is 2) and third class (Pclass is 3).

# %%
total_secondclass_fare = df[df['Pclass']==2]['Fare'].sum()
total_secondclass_fare
# Out:
# 3801.8417

# %% [markdown]
# Divide the totals for each class by the overall total fare to get the proportion of fare revenue by class.

# %%
fare_proportion_secondclass = total_secondclass_fare/total_fare
fare_proportion_secondclass
# Out:
# 0.1324962855496507

# %%
total_thirdclass_fare = df[df['Pclass']==3]['Fare'].sum()
total_thirdclass_fare
# Out:
# 6714.6951

# %% [markdown]
# Divide the totals for each class by the overall total fare to get the proportion of fare revenue by class.

# %%
fare_proportion_thirdclass = total_thirdclass_fare/total_fare
fare_proportion_thirdclass
# Out:
# 0.23401083726038366

# %% [markdown]
# Create a new column, age group, that categorizes passengers into "child" (age < 18), "adult" (age
# 18{64), and "senior" (age 65 and above).

# %%
def category_age(age):
  if age < 18:
    return 'child'
  elif age <=64:
    return 'adult'
  else:
    return 'senior'

df['age_group'] = df['Age'].apply(category_age)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  fare_per_class age_group
# 0      0         A/5 21171   7.2500   NaN        S        2.416667     adult
# 1      0          PC 17599  71.2833   C85        C       71.283300     adult
# 2      0  STON/O2. 3101282   7.9250   NaN        S        2.641667     adult
# ...

# %% [markdown]
# Calculate the total number of passengers on the Titanic.

# %%
total_passenger = df['PassengerId'].count()
total_passenger
# Out:
# 891

# %% [markdown]
# Count the number of passengers in each age group.

# %%
df['age_group'].value_counts()
# Out:
# age_group
# adult     590
# senior    188
# child     113
# Name: count, dtype: int64

# %% [markdown]
# Divide the count of each age group by the total number of passengers to get the proportion of passengers
# in each age group.

# %%
adult_proportion = df['age_group'].value_counts()['adult']/total_passenger
adult_proportion*100
# Out:
# 66.21773288439955

# %%
child_proportion = df['age_group'].value_counts()['child']/total_passenger
child_proportion*100
# Out:
# 12.682379349046016

# %%
senior_proportion = df['age_group'].value_counts()['senior']/total_passenger
senior_proportion*100
# Out:
# 21.099887766554435

# %% [markdown]
# Display the proportion as a percentage.

# %%
66.21773288439955 + 12.682379349046016 + 21.099887766554435
# Out:
# 100.0
