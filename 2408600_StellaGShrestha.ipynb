# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/WHR-2024-5CS037.csv")

# %% [markdown]
# Problem - 1: Getting Started with Data Exploration

# %% [markdown]
# Dataset Overview
# 1. Load the dataset and display the first 10 rows.

# %%
df.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %% [markdown]
# 2. Identify the number of rows and columns in the dataset.

# %%
print("The number of rows and columns in the dataser are: ")
df.shape
# Out:
# The number of rows and columns in the dataser are:
# (143, 9)

# %% [markdown]
# 3. List all the columns and their datta types

# %%
df.dtypes
# Out:
# Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %% [markdown]
# Basic Statistics
# 1. Calculate the mean, median, and standard deviation for the Score column.

# %%
mean = df['score'].mean()
median = df['score'].median()
std_dev = df['score'].std()
print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Standard ddeviation: {std_dev}")
# Out:
# Mean: 5.52758041958042
# Median: 5.785
# Standard ddeviation: 1.1707165099442995

# %% [markdown]
# 2. Identify the country with the highest and lowest happiness scores.

# %%
highest_score = df.loc[df['score'].idxmax()]
lowest_score = df.loc[df['score'].idxmin()]

print(f"The country with the highest happiness score is: {highest_score['Country name']} with a score of {highest_score['score']}")
print(f"The country with the lowest happiness score is: {lowest_score['Country name']} with a score of {lowest_score['score']}")
# Out:
# The country with the highest happiness score is: Finland with a score of 7.741
# The country with the lowest happiness score is: Afghanistan with a score of 1.721

# %% [markdown]
# Missing Values
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
missing_values = df.isnull().sum()#if not sum() then the answer will be in boolean
print(missing_values)
# Out:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# Filtering and Sorting
# 1. Filter the dataset to show only the countries with a Score greater than 7.5.

# %%
country=df[df['score']>7.5]
country
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
#
#    Perceptions of corruption  Dystopia + residual
# 0                      0.546                2.082
# 1                      0.548                1.881
# 2                      0.182                2.050

# %% [markdown]
# 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# top 10 rows.

# %%
sorted_data = df.sort_values(by = "Log GDP per capita", ascending=False)
sorted_data.head(10)
# Out:
#                  Country name  score  Log GDP per capita  Social support  \
# 7                  Luxembourg  7.122               2.141           1.355
# 16                    Ireland  6.838               2.129           1.390
# 29                  Singapore  6.523               2.118           1.361
# 21       United Arab Emirates  6.733               1.983           1.164
# 8                 Switzerland  7.060               1.970           1.425
# 6                      Norway  7.302               1.952           1.517
# 22              United States  6.725               1.939           1.392
# 85  Hong Kong S.A.R. of China  5.316               1.909           1.184
# 1                     Denmark  7.583               1.908           1.520
# 5                 Netherlands  7.319               1.901           1.462
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 7                     0.708                         0.801       0.146
# ...

# %% [markdown]
# Adding new columns
# 1. Create a new column called Happiness Category that categorizes countries into three categories
# based on their Score:
#
# Low − (Score < 4)
# Medium − (4 ≤ Score ≤ 6)
# High − (Score > 6)

# %%
happiness_category = []

for score in df['score']:
    if score < 4:
        happiness_category.append('Low')
    elif 4 <= score <= 6:
        happiness_category.append('Medium')
    else:
        happiness_category.append('High')

df['Happiness Category'] = happiness_category
#Happiness Category is created in dataframe and contains the values from happiness_category list
print(df)
# Out:
#          Country name  score  Log GDP per capita  Social support  \
# 0             Finland  7.741               1.844           1.572
# 1             Denmark  7.583               1.908           1.520
# 2             Iceland  7.525               1.881           1.617
# 3              Sweden  7.344               1.878           1.501
# 4              Israel  7.341               1.803           1.513
# ..                ...    ...                 ...             ...
# 138  Congo (Kinshasa)  3.295               0.534           0.665
# 139      Sierra Leone  3.245               0.654           0.566
# 140           Lesotho  3.186               0.771           0.851
# 141           Lebanon  2.707               1.377           0.577
# 142       Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.695                         0.859       0.142
# ...

# %% [markdown]
# Data Visualization
# • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.

# %%
import matplotlib.pyplot as plt

top_10_happiest = df.sort_values(by='score', ascending=False).head(10)
plt.figure(figsize=(8, 6))
plt.bar(top_10_happiest['Country name'], top_10_happiest['score'], color='skyblue', edgecolor='black')

plt.title('Top 10 Happiest Countries by Score')
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %% [markdown]
# Plot the top 10 unhappiest countries by Score using a Line chart.

# %%
top_10_unhappiest = df.sort_values(by='score',ascending=True).head(10)

plt.figure(figsize=(10,6))
plt.plot(top_10_unhappiest['Country name'],top_10_unhappiest['score'],marker='o',linestyle='--',color='g')
plt.title('Top 10 Unhappiest countries by Score')
plt.xlabel('Country')
plt.ylabel('Score')

plt.show()

# %% [markdown]
# Plot a histogram for the Score column to show its distribution and also interpret.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.hist(df['score'],bins=30,color='turquoise',edgecolor='black')
plt.title='Distribution of Score'
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
import matplotlib.pyplot as plt
x = df['Log GDP per capita']
y = df['score']

plt.scatter(x, y, color='blue', edgecolor='black', alpha=0.7)
plt.xlabel('GDP per capita')
plt.ylabel('Score')

plt.show()

# %% [markdown]
# Problem - 2 - Some Advance Data Exploration Task:

# %% [markdown]
# Task 1
# 1. Define the countries in South Asia with a list for example:
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India","Maldives", "Nepal", "Pakistan", "Srilanka"]
#
# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
# 3. Save the filtered dataframe as separate CSV files for future use.

# %%
south_asia = ['Afghanistan','Bangladesh','Bhutan','India','Maldives','Nepal','Pakistan','Sri Lanka']
filtered = df[df['Country name'].isin(south_asia)]
filtered.to_csv('/content/drive/MyDrive/Datasets/southasia.csv',index=False)
filtered
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# Task 2

# %%
south_asia = pd.read_csv('/content/drive/MyDrive/Datasets/southasia.csv')
south_asia
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 3    Sri Lanka  3.898               1.361           1.179
# 4   Bangladesh  3.886               1.122           0.249
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
# 5                    0.242                         0.000       0.091
#
#    Perceptions of corruption  Dystopia + residual Happiness Category
# ...

# %% [markdown]
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
#
# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support
#
# + 0.30 × Healthy Life Expectancy

# %%
south_asia['Composite Score'] = (0.40 * south_asia['Log GDP per capita'] + 0.30 * south_asia['Social support'] + 0.30 * south_asia['Healthy life expectancy'])
print(south_asia)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 3    Sri Lanka  3.898               1.361           1.179
# 4   Bangladesh  3.886               1.122           0.249
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
# 5                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# 2. Rank the South Asian countries based on the Composite Score in descending order.

# %%
south_asia = south_asia.sort_values(by='Composite Score',ascending = False)
south_asia.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 3    Sri Lanka  3.898               1.361           1.179
# 0        Nepal  5.158               0.965           0.990
# 2        India  4.054               1.166           0.653
# 1     Pakistan  4.657               1.069           0.600
# 4   Bangladesh  3.886               1.122           0.249
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 3                    0.586                         0.583       0.144
# 0                    0.443                         0.653       0.209
# 2                    0.417                         0.767       0.174
# 1                    0.321                         0.542       0.144
# 4                    0.513                         0.775       0.140
# 5                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.

# %%
top5 = south_asia.head(5)
plt.barh(top5['Country name'], top5['Composite Score'], color='skyblue')
plt.xlabel('Composite Score')
plt.ylabel('Country')
plt.gca().invert_yaxis()
#plt.title('Top 5 South Asia based on composite score')
plt.show()

# %% [markdown]
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your
# discussion with some visualization plot.

# %%
import numpy as np

south_asia['Original Rank'] = south_asia['score'].rank(ascending=False)
south_asia['Composite Rank'] = south_asia['Composite Score'].rank(ascending=False)
south_asiasort = south_asia.sort_values(by='Composite Rank')
top5 = south_asiasort.head(5)

plt.figure(figsize=(10,6))
x = np.arange(len(top5))
width = 0.4

plt.bar(x - width / 2, top5["Original Rank"], width, label="Original Rank", color="orange",edgecolor = 'black')
plt.bar(x + width / 2, top5["Composite Rank"], width, label="Composite Rank", color="red",edgecolor = 'black')

plt.xticks(x, top5["Country name"])
plt.xlabel("Country")
plt.ylabel("Rank")
plt.legend()
# plt.title('Composite Score')
plt.savefig("/content/drive/MyDrive/Datasets/rank.png", bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(south_asia['score'],south_asia['Composite Score'],color='red')
plt.xlabel('Original Happiness Score')
plt.ylabel('Composite Score')
plt.grid(True)
plt.show()

# %% [markdown]
# Task 3 - Outliers Detection
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
# 2. Define outliers using the 1.5 × IQR rule.
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %%
import matplotlib.pyplot as plt

Q1_score = south_asia['score'].quantile(0.25)
Q3_score = south_asia['score'].quantile(0.75)

IQR_score = Q3_score - Q1_score
lower_bound_score = Q1_score - 1.5 * IQR_score
upper_bound_score = Q3_score + 1.5 * IQR_score

Q1_gdp = south_asia['Log GDP per capita'].quantile(0.25)
Q3_gdp = south_asia['Log GDP per capita'].quantile(0.75)

IQR_gdp = Q3_gdp - Q1_gdp
lower_bound_gdp = Q1_gdp - 1.5 * IQR_gdp
upper_bound_gdp = Q3_gdp + 1.5 * IQR_gdp

outliers = south_asia[
    (south_asia["Log GDP per capita"] < lower_bound_gdp) |
    (south_asia["Log GDP per capita"] > upper_bound_gdp) |
    (south_asia["score"] < lower_bound_score) |
    (south_asia["score"] > upper_bound_score)
]

plt.figure(figsize=(10, 6))
plt.scatter(south_asia['Log GDP per capita'], south_asia['score'], label='Non-outliers', color='blue', alpha=0.7)
plt.scatter(outliers["Log GDP per capita"], outliers["score"], label="Outliers", color="red", alpha=0.9)

plt.xlabel("Log GDP per Capita")
plt.ylabel("Score")
# plt.title("Scatter Plot of Log GDP per Capita vs Score with Outliers Highlighted")
plt.legend()
plt.show()

# %% [markdown]
# Task 4 - Exploring Trends Across Metrics
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
# {pearson correlation} with the Score for South Asian countries.

# %%
freedom_correlation = south_asia['Freedom to make life choices'].corr(south_asia['score'])
print(f"Pearson Correlation between Freedom to Make Life Choices and Score: {freedom_correlation}")
generosity_correlation = south_asia['Generosity'].corr(south_asia['score'])
print(f"Pearson Correlation between Generosity and Score: {generosity_correlation}")
# Out:
# Pearson Correlation between Freedom to Make Life Choices and Score: 0.8005185224163315
# Pearson Correlation between Generosity and Score: 0.874512371253192

# %% [markdown]
# 2. Create scatter plots with trendlines for these metrics against the Score.

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='Freedom to make life choices', y='score', data=south_asia, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
# plt.title('Freedom to Make Life Choices vs Score')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='Generosity', y='score', data=south_asia, scatter_kws={'color': 'green'}, line_kws={'color': 'orange'})
# plt.title('Generosity vs Score')
plt.xlabel('Generosity')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for
# South Asian countries.

# %%
if freedom_correlation > generosity_correlation:
    print("Freedom to make life choices has a stronger correlation with happiness score.")
else:
    print("Generosity has a stronger correlation with happiness score.")
# Out:
# Generosity has a stronger correlation with happiness score.

# %% [markdown]
# Task 5 - Gap Analysis
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.

# %%
south_asia['GDP-Score Gap'] = south_asia['Log GDP per capita'] - south_asia['score']
print("The south asia data are:\n")
south_asia
# Out:
# The south asia data are:
#   Country name  score  Log GDP per capita  Social support  \
# 3    Sri Lanka  3.898               1.361           1.179
# 0        Nepal  5.158               0.965           0.990
# 2        India  4.054               1.166           0.653
# 1     Pakistan  4.657               1.069           0.600
# 4   Bangladesh  3.886               1.122           0.249
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 3                    0.586                         0.583       0.144
# 0                    0.443                         0.653       0.209
# 2                    0.417                         0.767       0.174
# 1                    0.321                         0.542       0.144
# 4                    0.513                         0.775       0.140
# 5                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# 2. Rank the South Asian countries by this gap in both ascending and descending order.

# %%
ascendingdf = south_asia.sort_values(by = 'GDP-Score Gap',ascending = True)
print("The ascending data are:\n")
ascendingdf.head(3)
# Out:
# The ascending data are:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
#
#    Perceptions of corruption  Dystopia + residual Happiness Category  \
# 0                      0.115                1.783             Medium
# 1                      0.074                1.907             Medium
# 2                      0.122                0.756             Medium
#
#    Composite Score  Original Rank  Composite Rank  GDP-Score Gap
# 0           0.8159            1.0             2.0         -4.193
# ...

# %%
decendingdf = south_asia.sort_values(by = 'GDP-Score Gap', ascending = False)
print("The decending data are: \n")
decendingdf.head(3)
# Out:
# The decending data are:
#   Country name  score  Log GDP per capita  Social support  \
# 5  Afghanistan  1.721               0.628           0.000
# 3    Sri Lanka  3.898               1.361           1.179
# 4   Bangladesh  3.886               1.122           0.249
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 5                    0.242                         0.000       0.091
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
#
#    Perceptions of corruption  Dystopia + residual Happiness Category  \
# 5                      0.088                0.672                Low
# 3                      0.031                0.014                Low
# 4                      0.167                0.919                Low
#
#    Composite Score  Original Rank  Composite Rank  GDP-Score Gap
# 5           0.3238            6.0             6.0         -1.093
# ...

# %% [markdown]
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.

# %%
top3 = ascendingdf.head(3)
low3 = decendingdf.head(3)
plt.barh(top3['Country name'], top3['GDP-Score Gap'], color='skyblue')
plt.xlabel('GDP-Score Gap')
plt.ylabel('Country name')
# plt.title('Top 3 Countries by GDP-Score Gap')
plt.show()
plt.barh(low3['Country name'], low3['GDP-Score Gap'], color='blue')
plt.xlabel('GDP-Score Gap')
plt.ylabel('Country name')
# plt.title('Low 3 Countries by GDP-Score Gap')
plt.show()

# %% [markdown]
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %% [markdown]
# Problem 3 - COmparative Analysis
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
#
# "United Arab Emirates", "Yemen"]

# %%
middle_east_country = ['Bahrain', 'Iran', 'Iraq', 'Israel','Jordan','Kuwait','Lebanon','Oman','Palestine','Qatar','Saudi Arabia','Syria','United Arab Emirates','Yemen']
middleast_df= df[df['Country name'].isin(middle_east_country)]
middleast_df.to_csv('/content/drive/MyDrive/Datasets/middleast.csv',index = False)
middleast_df
# Out:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 61                Bahrain  5.959                 NaN             NaN
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# ...

# %% [markdown]
# 1. Descriptive Statistics
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.
# • Which region has higher happiness Scores on average?

# %%
southmean = south_asia['score'].mean()
southstd = south_asia['score'].std()

middlemean = middleast_df['score'].mean()
middlestd = middleast_df['score'].std()


print("Descriptive Statistics for South Asia:")
print(f"Mean Score: {southmean:.2f}")
print(f"Standard Deviation:{southstd:.2f}")

print("\nDescriptive Statistics for Middle East:")
print(f"Mean Score: {middlemean:.2f}")
print(f"Standard Deviation: {middlestd:.2f}")

if southmean>middlemean:
   print("\nSouth Asia has higher happiness scores on average.")
else:
  print("\nMiddle East has higher happiness scores on average.")
# Out:
# Descriptive Statistics for South Asia:
# Mean Score: 3.90
# Standard Deviation:1.18
#
# Descriptive Statistics for Middle East:
# Mean Score: 5.41
# Standard Deviation: 1.57
#
# Middle East has higher happiness scores on average.

# %% [markdown]
# 2. Top and bottom Performers
#
# Identify the top 3 and bottom 3 countries in each region based on the score.
# • Plot bar charts comparing these charts.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sAsia_top = south_asia.nlargest(3, "score")
sAsia_bottom = south_asia.nsmallest(3, "score")

midEast_top = middleast_df.nlargest(3, "score")
midEast_bottom = middleast_df.nsmallest(3, "score")

plt.figure(figsize=(14, 8))
plt.subplot(1, 2, 1)
sns.barplot(x="score", y="Country name", data=pd.concat([sAsia_top, sAsia_bottom]),color = 'skyblue', edgecolor = 'black')
# plt.title("Top and Bottom 3 Countries - South Asia")
plt.xlabel("Score")
plt.ylabel("Country Name")

plt.subplot(1, 2, 2)
sns.barplot(x="score", y="Country name", data=pd.concat([midEast_top, midEast_bottom]), color = 'lavender',edgecolor = 'black')
# plt.title("Top and Bottom 3 Countries - Middle East")
plt.xlabel("Score")
plt.ylabel("Country Name")

plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Metric Comparisons
#
# Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy
# between the regions using grouped bar charts.
# • Which metrics show the largest disparity between the two regions?

# %%
compare = ["Log GDP per capita", "Social support", "Healthy life expectancy"]

south_mean = south_asia[compare].mean()
middle_mean = middleast_df[compare].mean()

comp_df = pd.DataFrame({"South Asia": south_mean, "Middle East": middle_mean})
comp_df.plot(kind="bar", figsize=(6,6), color=["red","orange"], edgecolor = 'black')
# plt.title("Comparison of key Metrics beteen south asia and middle east")
plt.ylabel("Average values")
plt.xlabel("Key Metrics")
plt.legend()
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# 4. Happiness Disparity
#
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
# • Which region has greater variability in happiness?

# %%
south_range = south_asia['score'].max() - south_asia['score'].min()
middle_range = middleast_df['score'].max() - middleast_df['score'].min()

print(f"The range of happiness score for South Asia is: {south_range:.2f}")
print(f"The range of happiness score for Middle East is: {middle_range:.2f}")

south_std = south_asia['score'].std()
south_mean = south_asia['score'].mean()
middle_std = middleast_df['score'].std()
middle_mean = middleast_df['score'].mean()

south_cv = (south_std / south_mean) * 100
middle_cv = (middle_std / middle_mean) * 100

print(f"The coefficient of variation for South Asia is: {south_cv:.2f}%")
print(f"The coefficient of variation for Middle East is: {middle_cv:.2f}%")

if south_cv>middle_cv:
    print("\nSouth Asia has greater variablity in happiness.")
else:
   print("\nMiddle East has greater variablity in happiness")
# Out:
# The range of happiness score for South Asia is: 3.44
# The range of happiness score for Middle East is: 4.63
# The coefficient of variation for South Asia is: 30.21%
# The coefficient of variation for Middle East is: 28.94%
#
# South Asia has greater variablity in happiness.

# %% [markdown]
# 5. Correlation Analysis
#
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and
# Generosity within each region.
# • Create scatter plots to visualize and interpret the relationships.

# %%
metrics=["Freedom to make life choices","Generosity"]

for m in metrics:
  print(f"Correlation of Score with {m}")
  print("South Asia:", south_asia['score'].corr(south_asia[m]))
  print("Middle East:", middleast_df['score'].corr(middleast_df[m]))

for m in metrics:
  plt.figure(figsize=(10,6))
  plt.subplot(1,2,1)
  sns.scatterplot(x=m, y="score",data=south_asia)
  # plt.title(f"South Asia Correlation (Score with {m})")
  plt.tight_layout()
  plt.show()

  plt.figure(figsize=(10,6))
  plt.subplot(1,2,1)
  sns.scatterplot(x=m, y="score",data=middleast_df)
  # plt.title(f"Middle East Correlation (Score with {m})")
  plt.tight_layout()
  plt.show()
# Out:
# Correlation of Score with Freedom to make life choices
# South Asia: 0.8005185224163315
# Middle East: 0.8632202433827544
# Correlation of Score with Generosity
# South Asia: 0.874512371253192
# Middle East: 0.6275236536964182

# %% [markdown]
# 6. Outlier Detection
#
# • Identify outlier countries in both regions based on Score and GDP per Capita.
# • Plot these outliers and discuss their implications.

# %%
def outlier(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower) | (df[column] > upper)]
    return outliers

sAsian_out_score=outlier(south_asia,"score")
midEast_out_score=outlier(middleast_df,"score")

sAsian_out_gdp=outlier(south_asia,"score")
midEast_out_gdp=outlier(middleast_df,"score")

sAsian_outliers=pd.concat([sAsian_out_score,sAsian_out_gdp]).drop_duplicates()
midEast_outliers=pd.concat([midEast_out_score,midEast_out_gdp]).drop_duplicates()

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.scatterplot(data=sAsian_outliers, x='Log GDP per capita', y='score', label='Outliers')
# plt.title("South Asia: outlier countries based on Score and GDP per Capita")
plt.xlabel("Log GDP per Capita")
plt.ylabel("Score")

plt.subplot(1, 2, 2)
sns.scatterplot(data=midEast_outliers, x='Log GDP per capita', y='score', label='Outliers')
# plt.title("Middle East: outlier countries based on Score and GDP per Capita")
plt.xlabel("Log GDP per Capita")
plt.ylabel("Score")

plt.tight_layout()
plt.show()

# %% [markdown]
# 7. Visualization
#
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
# • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.boxplot(x='Region', y='score',data=pd.concat([south_asia.assign(Region="South Asia"),middleast_df.assign(Region="Middle East")]))
# plt.title(" Distribution of Score between South Asia and the Middle East")
plt.show()
